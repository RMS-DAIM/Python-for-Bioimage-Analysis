# %% [markdown]
# # Testing utility methods
# (Add information here)
# ________

# %% [markdown]
# # Importing dependencies

# %%
import util

# %% [markdown]
# # Testing image loading

# %%
# Testing image loading
path = "/home/scross/Downloads/Fluo-N2DH-GOWT1/01/"
util.load_images(path);
# Out:
# Loading images from " /home/scross/Downloads/Fluo-N2DH-GOWT1/01/ "
#
# Reading image 92 of 92
# Loaded image shape:  (342, 342, 92)

# %% [markdown]
# # Testing coordinate loading

# %%
# Testing coordinate loading
path = "../data/UntrackedCoordinates.csv"
util.load_coordinates(path);
# Out:
# Loading coordinates from " ../data/UntrackedCoordinates.csv "
# Loaded data shape:  (8639, 6)

# %% [markdown]
# # Testing track renders

# %%
# %%html
# <style>
# .output_wrapper button.btn.btn-default,
# .output_wrapper .ui-dialog-titlebar {
#   display: none;
# }
# </style>
# Out:
# <style>
# .output_wrapper button.btn.btn-default,
# .output_wrapper .ui-dialog-titlebar {
#   display: none;
# }
# </style>

# %%
# %matplotlib notebook
import util

# Loading image stack
path = "/home/scross/Downloads/Fluo-N2DH-GOWT1/01/"
images = util.load_images(path);

# Loading coordinates
path = "../data/TrackedCoordinates2.csv"
coords = util.load_coordinates(path);

# Adding track renders
util.show_overlay(images,coords,False)
# Out:
# Loading images from " /home/scross/Downloads/Fluo-N2DH-GOWT1/01/ "
#
# Reading image 92 of 92
# Loaded image shape:  (342, 342, 92)
# Loading coordinates from " ../data/TrackedCoordinates2.csv "
# Loaded data shape:  (2058, 6)
#
# Rendering frame 92 of 92
# <img src="data:image/png;base64,..." width="800">
# interactive(children=(IntSlider(value=0, description='frame', max=91), Output()), _dom_classes=('widget-intera…
